# %%
# numeric data

# %% [markdown]
# # numeric data

# %%
a=2
b=3
a+b
# Out:
# 5

# %% [markdown]
# # string

# %%
s1 = "Hello world"
print(s1)
# Out:
# Hello world

# %% [markdown]
# # data type : list

# %%
x = [1,2,3]
y = [4,5,6] 
x+y
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# # function

# %%
def add (a,b):
    return a+b

# %%
print(add(1,2))
add(x,y)
# Out:
# 3
# [1, 2, 3, 4, 5, 6]
