# %% [markdown]
# ## ch2-exercises-PB02.ipynb

# %% [markdown]
# ## Q1.
# > 홍길동 씨의 과목별 점수는 다음과 같다. 홍길동 씨의 평균 점수를 구해 보자.
#
# - 과목	점수
# - 국어	80
# - 영어	75
# - 수학	55

# %%
# [Q1] Code
a = 80
b = 75
c = 55
(a+b+c)/3
# Out:
# 70.0

# %% [markdown]
# ## Q2.
# > 자연수 13이 홀수인지 짝수인지 판별할 수 있는 방법에 대해 말해 보자.
#
# 1. 판별 기준
# 2. 코드

# %%
# [Q2] Code
# 1. 판별 기준 :  2로 나누었을 때, 나머지가 1이 나오면 홀수이다.
13%2
# Out:
# 1

# %% [markdown]
# ## Q3.
# > 홍길동 씨의 주민등록번호는 881120-1068234이다. 홍길동 씨의 주민등록번호를 연월일(YYYYMMDD) 부분과 그 뒤의 숫자 부분으로 나누어 출력해 보자.
#
# - 문자열 슬라이싱 기법을 사용해 보자.

# %%
# [Q3] Code
yyyymmdd = [881120]
yyyymmdd[:6]
num = [1068234]
num [:7]
print(yyyymmdd)
print(num)
# Out:
# [881120]
# [1068234]

# %% [markdown]
# ## Q4.
# > 주민등록번호 뒷자리의 맨 첫 번째 숫자는 성별을 나타낸다. 주민등록번호에서 성별을 나타내는 숫자를 출력해 보자.
#
# - pin = "881120-1068234"
# - ※ 문자열 인덱싱 또는 내장함수를 사용해 보자.
# - 문자열포맷팅을 이용해서 성별을 출력하시오.

# %%
# [Q4] Code
pin = "881120-1068234"
a = pin[7:8]
a
# Out:
# '1'

# %% [markdown]
# ## Q5.
# > 다음과 같은 문자열 a:b:c:d가 있다. 문자열의 replace 함수를 사용하여 a#b#c#d로 바꿔서 출력해 보자.
#
# - a = "a:b:c:d"

# %%
# [Q5] Code
a = "a:b:c:d"
b= a.replace(":","#")
b
# Out:
# 'a#b#c#d'

# %% [markdown]
# ## Q6.
# > \[1, 3, 5, 4, 2\] 리스트를 \[5, 4, 3, 2, 1\]로 만들어 보자.
#
# - ※ 리스트의 내장 함수를 사용해 보자.

# %%
# [Q6] Code
a=[1,3,5,4,2]
a.sort()
a.reverse()
a
# Out:
# [5, 4, 3, 2, 1]

# %% [markdown]
# ## Q7.
# > \['Life', 'is', 'too', 'short'\] 리스트를 Life is too short 문자열로 만들어 출력해 보자.
#
# - ※ 문자열의 join 함수를 사용하면 리스트를 문자열로 쉽게 만들 수 있다.

# %%
# [Q7] Code
a = ['Life', 'is', 'too', 'short']
b =" ".join(a)
b
# Out:
# 'Life is too short'

# %% [markdown]
# ## Q8.
# > (1,2,3) 튜플에 값 4를 추가하여 (1,2,3,4)를 만들어 출력해 보자.
#
# - ※ 더하기(+) 또는 다른 방법들을 사용해 보자.

# %%
# [Q8] Code
a = (1,2,3)
a = a+(4,)
a
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# ## Q9.
# > 다음과 같은 딕셔너리 a가 있다.
#
# >> a = dict()
# >> a
# {}
#
# - 다음 중 오류가 발생하는 경우를 고르고, 그 이유를 설명해 보자.
#
# 1. a\['name'\] = 'python'
# 2. a\[('a',)\] = 'python'
# 3. a\[\[1\]\] = 'python'
# 4. a\[250\] = 'python'

# %%
# [Q9] Code & explanation
1번과 3번은  list 여서 오류이고
2번과 4번은 튜플과 정수구조로 되있어서 변하지않습니다.
# Out:
#   File "<ipython-input-10-6702fac5cb2e>", line 2
#     1번과 3번은  list 여서 오류이고
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Q10.
# > 딕셔너리 a에서 'B'에 해당되는 값을 추출해 보자.
# >> a = {'A':90, 'B':80, 'C':70}
#
# - ※ 딕셔너리의 pop 함수를 사용해 보자.

# %%
# [Q10] Code
a = {'A':90, 'B':80, 'C':70}
a.pop('B')
# Out:
# 80

# %% [markdown]
# ## Q11.
# > a 리스트에서 중복 숫자를 제거해 보자.
# >> a = \[1, 1, 1, 2, 2, 3, 3, 3, 4, 4, 5\]
#
# - ※ 집합 자료형의 요솟값이 중복될 수 없다는 특징을 사용해 보자.

# %%
# [Q11] Code
a = set([1,1,1,2,2,3,3,3,4,4,5])
a
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ## Q12.
# > 파이썬은 다음처럼 동일한 값에 여러 개의 변수를 선언할 수 있다. 다음과 같이 a, b 변수를 선언한 후 a의 두 번째 요솟값을 변경하면 b 값은 어떻게 될까? 그리고 이런 결과가 오는 이유에 대해 설명해 보자.
#
# >> a = b = \[1, 2, 3\]
# >> a\[1\] = 4
# >> print(b)

# %%
# [Q12] Code & explanation
출력을하면 [1, 4, 3] 이출력된다 그이유는 a = b이고  a의값은 b에게도 같이적용된다 .
# Out:
#   File "<ipython-input-13-f2bb849f0c2d>", line 2
#     출력을하면 [1, 4, 3] 이출력된다 그이유는 a = b이고  a의값은 b에게도 같이적용된다 .
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 코딩 연습 결과를 github에 올리기
# > 완성된 ipython 노트북 파일을 각자의 github에 올리시오.
#
# - github 계정 만들기 (계정이 없는 학생)
#     1. github에 sign up (Google gmail 계정을 이용해서 만드시오.)
# - github에 노트 올리기
#     2. github에 각자의 id로 repo를 만드시오. (한번 만들면 계속 재사용)
#     3. **github repo의 ch2 폴더에 연습문제 풀이 노트를 올리시오.**
#         - 제출노트: ch2-exercises-id.ipynb
